# %%
import subprocess
import sys

def instalar_librerias(librerias):
    for libreria in librerias:
        try:
            # Intentamos importar la librería
            __import__(libreria)
            print(f'La librería {libreria} ya está instalada.')
        except ImportError:
            # Si no se puede importar, la instalamos
            print(f'La librería {libreria} no está instalada. Instalando...')
            subprocess.check_call([sys.executable, "-m", "pip", "install", libreria])

# %%
instalar_librerias(['beautifulsoup4', 'undetected-chromedriver', 'pandas', 'selenium', 'setuptools'])
# Out:
# La librería beautifulsoup4 no está instalada. Instalando...
# La librería undetected-chromedriver no está instalada. Instalando...
# La librería pandas ya está instalada.
# La librería selenium ya está instalada.
# La librería setuptools ya está instalada.

# %%
import requests
from bs4 import BeautifulSoup as bs
import random
import time
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc
import time

# %% [markdown]
# # Saga Falabella Web Scraping

# %%
#Código para ingresar a la página de Saga Falabella

def acceso(url):
    browser=uc.Chrome()
    browser.get(url)

    browser.implicitly_wait(25)

    browser.refresh()
    #Cerrar ventana de suscripcion
    #align-right primary slidedown-button
    browser.find_element("xpath",'//*[@id="testId-accept-cookies-btn"]').click()
    browser.implicitly_wait(25)

    html=browser.page_source
    soup=bs(html, "html.parser")

    #Al terminar el proceso cierro la pestaña
    browser.close()
    #Cierro el navegador
    browser.quit()

    return soup

# %%
#Extraer texto
def text_extract(textos):
    lista=[]
    for texto in textos:
        lista.append(texto.text)
    return lista

#Extraer precio
def prices_extract(precios):
    lista=[]
    for precio in precios:
        lista.append(precio.text.strip()[3:])
    return lista

# %%
#Función para cambiar de páginas
#enlace
url="https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos"
def next_page(enlace,pagina):
    enlace=enlace+"?page={}"
    enlace=enlace.format(pagina)
    return enlace

for i in range(1,7):
    print(next_page(url,i))
# Out:
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=1
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=2
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=3
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=4
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=5
# https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=6

# %%
url="https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos"
items_categoria=[]
marcas_categoria=[]
precios_categoria=[]


for i in range(1,2):
    #Genera el enlace de la página i
    url_page=next_page(url,i)
    #Obtiene el html de la página i
    soup=acceso(url_page)

    print(soup)

    #Encuentra los items, marcas y precios en el html de la página i
    items=soup.find_all("div", {"class":"jsx-184544934 copy5 primary  jsx-3451706699 normal   line-clamp line-clamp-3     pod-subTitle subTitle-rebrand"})
    marcas=soup.find_all("div", {"class":"jsx-184544934 title5 secondary  jsx-3451706699 bold        pod-title title-rebrand"})
    precios=soup.find_all("span", {"class":"copy10 primary medium jsx-3451706699 normal       line-height-22"})

    #Extra los items, marcas y precios de la página i
    items_list=text_extract(items)
    marcas_list=text_extract(marcas)
    precios_list=prices_extract(precios)



    #Coloca todos los elementos en una listas globales
    items_categoria.append(items_list)
    marcas_categoria.append(marcas_list)
    precios_categoria.append(precios_list)


#Como nuestro resultado será una lista de listas
#La siguiente función las coloca en una sola
#Ejemplo A=[[1,2], [3,4],[5,6]]
#Retorna A=[1,2,3,4,5,6]

def unir_listas(lista_de_listas):
    """
    Convierte una lista de listas en una sola lista usando un bucle.

    :param lista_de_listas: Lista de listas a unir.
    :return: Lista unificada.
    """
    resultado = []
    for sublista in lista_de_listas:
        resultado.extend(sublista)
    return resultado


items_categoria=unir_listas(items_categoria)
marcas_categoria=unir_listas(marcas_categoria)
precios_categoria=unir_listas(precios_categoria)

df=pd.DataFrame({
    "Item":items_categoria,
    "Marca":marcas_categoria,
    "Precio":precios_categoria
    })
df["categoria"]="Calzado"
df
# Out:
# <html lang="es"><head class="vwo_loaded vwo_loaded_23"><meta content="com.falabella.app" property="al:ios:package"/><meta content="com.falabella.falabellaApp" property="al:android:package"/><meta content="Falabella" property="al:android:app_name"/><meta content="https://play.google.com/store/apps/details?id=com.falabella.falabellaApp" property="al:android:url"/><meta content="Falabella" property="al:ios:app_name"/><meta content="947145705" property="al:ios:app_store_id"/><meta content="https://apps.apple.com/cl/app/falabella/id947145705" property="al:ios:url"/><meta content="https://www.falabella.com.pe/falabella-pe/collection/ver-todo-zapatos?page=1" property="al:web:url"/><style>body { margin: 0 } /* custom! */</style><meta charset="utf-8" class="next-head"/><script async="" src="https://s.pinimg.com/ct/core.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://analytics
# ...
